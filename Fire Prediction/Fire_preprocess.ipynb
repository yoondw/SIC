# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
fire_all = pd.read_csv('./fire_all.csv', encoding = 'cp949')
fire_all.head()
# Out:
# C:\Users\caand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,172,173,174,175,176,177,178,179) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            dt_of_fr fr_yn bldng_us bldng_archtctr  bldng_cnt  bldng_ar  \
# 0  2017-10-20 05:54     Y     단독주택           블록구조          3     69.42
# 1  2018-09-30 08:26     N      NaN            NaN          3     46.29
# 2  2016-10-30 14:57     Y     공동주택       철근콘크리트구조          1    583.80
# 3  2016-06-14 05:23     N     단독주택          일반목구조          2     48.92
# 4  2018-04-22 05:38     N      NaN            NaN          2      0.00
#
#     ttl_ar  lnd_ar dt_of_athrztn  ttl_grnd_flr  ...  no_tbc_zn_dstnc  \
# 0    69.42     0.0        1977.0           1.0  ...               88
# 1    46.29     0.0           NaN           1.0  ...             7727
# ...

# %%
fire_feature = fire_all.iloc[:, [1,4,5,6,7,9,10,12,14,16,158,159,160,161,162,164,165,166,167,168,169,170,171]]

# %%
fire_feature
# Out:
#       fr_yn  bldng_cnt  bldng_ar   ttl_ar   lnd_ar  ttl_grnd_flr  ttl_dwn_flr  \
# 0         Y          3     69.42    69.42     0.00           1.0          0.0
# 1         N          3     46.29    46.29     0.00           1.0          0.0
# 2         Y          1    583.80  2516.76  1446.00           5.0          0.0
# 3         N          2     48.92    48.92     0.00           1.0          0.0
# 4         N          2      0.00     0.00     0.00           NaN          NaN
# ...     ...        ...       ...      ...      ...           ...          ...
# 66092     N          1      0.00     0.00     0.00           NaN          NaN
# 66093     N          1    186.00   340.74   945.00           2.0          0.0
# 66094     Y          1    115.50   290.40   583.86           3.0          0.0
# 66095     N          1    139.05   378.84   234.10           3.0          0.0
# 66096     Y          1    509.32  2669.72  1008.40           7.0          0.0
#
# ...

# %%
fire_feature.describe()
# Out:
#           bldng_cnt       bldng_ar        ttl_ar        lnd_ar  ttl_grnd_flr  \
# count  66097.000000   66097.000000  6.609700e+04  6.609700e+04  55092.000000
# mean       3.326505     709.930469  3.234041e+03  2.708495e+04      3.587272
# std        6.919706    9412.103821  8.273613e+04  2.043907e+06     18.599150
# min        1.000000       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        1.000000      49.590000  5.421000e+01  0.000000e+00      1.000000
# 50%        2.000000      93.140000  1.014900e+02  1.861000e+02      1.000000
# 75%        4.000000     170.860000  2.614000e+02  4.840000e+02      2.000000
# max      705.000000  572897.955000  1.235184e+07  2.038984e+08    594.000000
#
#         ttl_dwn_flr        tmprtr       wnd_spd          hmdt         hm_cnt  \
# count  54167.000000  66083.000000  66060.000000  66072.000000   65395.000000
# mean       0.141378     14.125766      1.600772     65.416425   12916.961190
# ...

# %%
fire_feature = fire_feature.dropna(axis = 0)
fire_feature.describe()
# Out:
#          bldng_cnt       bldng_ar        ttl_ar        lnd_ar  ttl_grnd_flr  \
# count  37035.00000   37035.000000  3.703500e+04  3.703500e+04  37035.000000
# mean       3.04061     417.520751  4.199096e+03  2.838194e+03      3.989766
# std        3.71482    5117.667807  1.063935e+05  1.408510e+05     22.025275
# min        1.00000       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        1.00000      61.660000  6.666000e+01  0.000000e+00      1.000000
# 50%        2.00000      91.910000  9.961000e+01  1.980000e+02      1.000000
# 75%        4.00000     132.725000  1.941150e+02  3.900000e+02      2.000000
# max      117.00000  339687.880000  1.235184e+07  2.274090e+07    594.000000
#
#         ttl_dwn_flr        tmprtr       wnd_spd          hmdt         hm_cnt  \
# count  37035.000000  37035.000000  37035.000000  37035.000000   37035.000000
# mean       0.136790     14.165670      1.594127     65.478828   13834.905333
# ...

# %%
fire_feature = fire_feature.reset_index(drop = True)
fire_feature
# Out:
#       fr_yn  bldng_cnt  bldng_ar   ttl_ar  lnd_ar  ttl_grnd_flr  ttl_dwn_flr  \
# 0         N          3     46.29    46.29     0.0           1.0          0.0
# 1         Y          1    583.80  2516.76  1446.0           5.0          0.0
# 2         N          2     48.92    48.92     0.0           1.0          0.0
# 3         Y          1     96.66   149.04   486.0           2.0          0.0
# 4         N          6     92.00    92.04     0.0           1.0          0.0
# ...     ...        ...       ...      ...     ...           ...          ...
# 37030     N          1     96.48    96.48   310.0           1.0          0.0
# 37031     N          1    117.72   340.20   197.8           3.0          0.0
# 37032     N          1    186.00   340.74   945.0           2.0          0.0
# 37033     N          1    139.05   378.84   234.1           3.0          0.0
# 37034     Y          1    509.32  2669.72  1008.4           7.0          0.0
#
# ...

# %%
for i in range(len(fire_feature)):
    if fire_feature['bldng_ar'][i] == 0:
        fire_feature['bldng_ar'][i] = None
    if fire_feature['ttl_ar'][i] == 0:
        fire_feature['ttl_ar'][i] = None
    if fire_feature['lnd_ar'][i] == 0:
        fire_feature['lnd_ar'][i] = None
    if fire_feature['ttl_grnd_flr'][i] == 0:
        fire_feature['ttl_grnd_flr'][i] = None
    if fire_feature['wnd_spd'][i] == 0:
        fire_feature['wnd_spd'][i] = None
    if fire_feature['hmdt'][i] == 0:
        fire_feature['hmdt'][i] = None
# Out:
# <ipython-input-37-96f775bb006d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fire_feature['lnd_ar'][i] = None
# <ipython-input-37-96f775bb006d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fire_feature['wnd_spd'][i] = None
# <ipython-input-37-96f775bb006d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fire_feature['hmdt'][i] = None
# <ipython-input-37-96f775bb006d>:3: SettingWithCopyWarning:
# ...

# %%
fire_feature = fire_feature.dropna(axis = 0)
fire_feature = fire_feature.reset_index(drop = True)
fire_feature.describe()
# Out:
#           bldng_cnt       bldng_ar         ttl_ar        lnd_ar  ttl_grnd_flr  \
# count  22322.000000   22322.000000   22322.000000  2.232200e+04  22322.000000
# mean       2.554341     245.057264    1283.395998  4.567998e+03      2.697339
# std        2.996456    2081.371779   16464.519379  1.809093e+05     11.606057
# min        1.000000       4.750000       4.750000  1.562000e+00      1.000000
# 25%        1.000000      72.800000      78.127500  2.104000e+02      1.000000
# 50%        2.000000      99.785000     116.780000  3.180000e+02      1.000000
# 75%        3.000000     140.795000     233.822500  5.370000e+02      2.000000
# max      117.000000  159966.100000  727058.154000  2.274090e+07    413.000000
#
#         ttl_dwn_flr        tmprtr       wnd_spd          hmdt         hm_cnt  \
# count  22322.000000  22322.000000  22322.000000  22322.000000   22322.000000
# mean       0.098244     14.388563      1.704018     64.461952   15283.599901
# ...

# %%
fire_feature
# Out:
#       fr_yn  bldng_cnt  bldng_ar   ttl_ar  lnd_ar  ttl_grnd_flr  ttl_dwn_flr  \
# 0         Y          1    583.80  2516.76  1446.0           5.0          0.0
# 1         Y          1     96.66   149.04   486.0           2.0          0.0
# 2         Y          2     98.96    98.96   310.0           1.0          0.0
# 3         N          1     44.22   129.55    82.0           3.0          0.0
# 4         Y          4     81.36    81.36   640.0           1.0          0.0
# ...     ...        ...       ...      ...     ...           ...          ...
# 22317     N          1     96.48    96.48   310.0           1.0          0.0
# 22318     N          1    117.72   340.20   197.8           3.0          0.0
# 22319     N          1    186.00   340.74   945.0           2.0          0.0
# 22320     N          1    139.05   378.84   234.1           3.0          0.0
# 22321     Y          1    509.32  2669.72  1008.4           7.0          0.0
#
# ...
